# %% [markdown]
# ### 01.10 Gradient Descent - 리뷰

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('VEts6lhB4P0')

# %% [markdown]
# ### 01.10 Gradient Descent (Andrew Ng) - 한국어 자막

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('sZ3m8DSdA28')

# %% [markdown]
# ![1](nb_images/01.10.1.jpg)
# ![1](nb_images/01.10.2.jpg)
# ![1](nb_images/01.10.3.jpg)
# ![1](nb_images/01.10.4.jpg)
# ![1](nb_images/01.10.5.jpg)
